# %%
## install finrl library
# !sudo apt install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (754 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package swig4.0.
# (Reading database ... 120893 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-d3xyjn0i
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-d3xyjn0i
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit b781b80727bb8848e7addcfd6fa61e1ff6b06fa3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-3bv1kver/elegantrl_a7621498c3464c0aa895c527a0a57fde
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-3bv1kver/elegantrl_a7621498c3464c0aa895c527a0a57fde
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 4c1893aeeb350e952bdcce916b13e6650a84cd68
#   Preparing metadata (setup.py) ... done
# Collecting alpaca-trade-api<4,>=3 (from finrl==0.3.6)
#   Downloading alpaca_trade_api-3.0.2-py3-none-any.whl (34 kB)
# Collecting ccxt<4,>=3 (from finrl==0.3.6)
#   Downloading ccxt-3.1.60-py2.py3-none-any.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 17.5 MB/s eta 0:00:00
# Collecting exchange-calendars<5,>=4 (from finrl==0.3.6)
#   Downloading exchange_calendars-4.2.8-py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.4/191.4 kB 18.6 MB/s eta 0:00:00
# Collecting jqdatasdk<2,>=1 (from finrl==0.3.6)
#   Downloading jqdatasdk-1.9.0-py3-none-any.whl (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.9/165.9 kB 18.6 MB/s eta 0:00:00
# Collecting pyfolio<0.10,>=0.9 (from finrl==0.3.6)
#   Downloading pyfolio-0.9.2.tar.gz (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyportfolioopt<2,>=1 (from finrl==0.3.6)
#   Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 6.6 MB/s eta 0:00:00
# Collecting ray[default,tune]<3,>=2 (from finrl==0.3.6)
#   Downloading ray-2.6.3-cp310-cp310-manylinux2014_x86_64.whl (56.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (1.2.2)
# Collecting stable-baselines3[extra]>=2.0.0a5 (from finrl==0.3.6)
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 18.3 MB/s eta 0:00:00
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.6)
#   Downloading stockstats-0.5.4-py2.py3-none-any.whl (21 kB)
# Collecting wrds<4,>=3 (from finrl==0.3.6)
#   Downloading wrds-3.1.6-py3-none-any.whl (12 kB)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.10/dist-packages (from finrl==0.3.6) (0.2.28)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.5.3)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.23.5)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.31.0)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.6.2)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.0 MB/s eta 0:00:00
# Collecting msgpack==1.0.3 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 25.6 MB/s eta 0:00:00
# Collecting aiohttp==3.8.2 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading aiohttp-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.9 MB/s eta 0:00:00
# Collecting PyYAML==6.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 44.3 MB/s eta 0:00:00
# Collecting deprecation==2.1.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.1.0)
# Collecting charset-normalizer<3.0,>=2.0 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting multidict<6.0,>=4.5 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading multidict-5.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.1)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (67.7.2)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (2023.7.22)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (41.0.3)
# Collecting aiodns>=1.1.1 (from ccxt<4,>=3->finrl==0.3.6)
#   Downloading aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting pyluach (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2023.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.0)
# Collecting korean-lunar-calendar (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.10/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (2.0.20)
# Collecting thriftpy2>=0.3.9 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading thriftpy2-0.4.16.tar.gz (643 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 643.4/643.4 kB 44.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pymysql>=0.7.6 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.1)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.10.1)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.2)
# Collecting empyrical>=0.5.0 (from pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /usr/local/lib/python3.10/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.12.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.19.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.20.3)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.57.0)
# Collecting aiohttp-cors (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorful (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 19.6 MB/s eta 0:00:00
# Collecting py-spy>=0.2.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.2 MB/s eta 0:00:00
# Collecting gpustat>=1.0.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading gpustat-1.1.1.tar.gz (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 11.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting opencensus (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 11.3 MB/s eta 0:00:00
# Collecting pydantic<2 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.17.1)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (6.3.0)
# Collecting virtualenv<20.21.1,>=20.0.24 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 61.8 MB/s eta 0:00:00
# Collecting tensorboardX>=1.9 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (9.0.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.2.0)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.8.0.76)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.5.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.12.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.5.2)
# Collecting shimmy[atari]~=1.1.0 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading Shimmy-1.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting psycopg2-binary (from wrds<4,>=3->finrl==0.3.6)
#   Downloading psycopg2_binary-2.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 92.6 MB/s eta 0:00:00
# Collecting SQLAlchemy>=1.2.8 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading SQLAlchemy-1.4.49-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.25.2)
# Collecting pycares>=4.0.0 (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6)
#   Downloading pycares-4.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 27.0 MB/s eta 0:00:00
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 29.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.15.1)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.3)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.10/dist-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading nvidia_ml_py-12.535.108-py3-none-any.whl (36 kB)
# Collecting blessed>=1.17.1 (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.7.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Collecting jedi>=0.16 (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.1.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.3 MB/s eta 0:00:00
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (2.0.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.41.2)
# Collecting ply<4.0,>=3.4 (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (16.0.6)
# Collecting distlib<1,>=0.3.6 (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 44.3 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (3.10.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 34.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 69.8 MB/s eta 0:00:00
# Collecting swig==4.* (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 74.5 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.9.2)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.11.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.0.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.60.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)
# WARNING: The candidate selected for download or install is a yanked version: 'aiohttp' candidate (version 3.8.2 at https://files.pythonhosted.org/packages/8f/52/ea1e5eac3e748a94fdaafba5ab68adfb833f0cbdb68cc8149fbba5574176/aiohttp-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/aiohttp/) (requires-python:>=3.6))
# Reason for being yanked: This version includes overly restrictive multidict upper boundary disallowing multidict v6+. The previous patch version didn't have that and this is now causing dependency resolution problems for the users who have an "incompatible" version pinned. This is not really necessary anymore and will be addressed in the next release v3.8.3
#
# https://github.com/aio-libs/aiohttp/pull/6950
# Building wheels for collected packages: finrl, pyfolio, elegantrl, empyrical, gpustat, thriftpy2, box2d-py, AutoROM.accept-rom-license
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.6-py3-none-any.whl size=4669370 sha256=eba0204069cbf32dd8164fde82a5448336073d2eca9b6b4a223f0c554149988f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vfvvh7_m/wheels/72/3b/1a/0fc805a8cc65ecd5bfe4f74a3c586b6075678b8ba53fd8f749
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2-py3-none-any.whl size=88649 sha256=1428994e9bad8446e0b2ccdd6ab43a9a2c01e486fe1d73fe825e08e9f102183d
#   Stored in directory: /root/.cache/pip/wheels/71/38/bc/e53700cfd8b0ad6b539d2fbaaf060ed8a299e7622a5b86ef42
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=elegantrl-0.3.6-py3-none-any.whl size=197329 sha256=dd5c9021a3636e87f14b18776499e227da0be344384362b7c31eab900338e24b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vfvvh7_m/wheels/c0/51/a5/b05f165548221bc570f7223babd33e2992fa873cdcebe2d229
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39755 sha256=1ecade87f7a2863eaeb4677be0e138be75ff19bb1aaea89a847383c6e37dab7c
#   Stored in directory: /root/.cache/pip/wheels/0e/2e/f2/d6d2d9a1eb8fbbd9949bb5d4c00f753e3b74e5bd7ed10b1d36
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1.1-py3-none-any.whl size=26411 sha256=a9e3f8e4ec75402ed0267c5aa46fd219b59fa606cb8ffeac0040e861800572a0
#   Stored in directory: /root/.cache/pip/wheels/ec/d7/80/a71ba3540900e1f276bcae685efd8e590c810d2108b95f1e47
#   Building wheel for thriftpy2 (setup.py) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.4.16-cp310-cp310-linux_x86_64.whl size=1078686 sha256=537ce09e76b0872e733e392eaf88f5d048f0c7694121cbd925f4d44dd2d7a0ec
#   Stored in directory: /root/.cache/pip/wheels/95/f5/1d/fe404692e1c8aaea45220c322d1d0f32c9fd40eb0e2bdd571e
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2349113 sha256=164030e1c5389661932a1c7ab3eb2fe02c22ee3f413250de306288ee36c3ce61
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=6d304754f2b6e1fa3aa5916385e5f3f72dc4c2933787415ac4fc7ff92812628c
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built finrl pyfolio elegantrl empyrical gpustat thriftpy2 box2d-py AutoROM.accept-rom-license
# Installing collected packages: swig, py-spy, ply, opencensus-context, nvidia-ml-py, msgpack, korean-lunar-calendar, farama-notifications, distlib, colorful, box2d-py, websockets, virtualenv, urllib3, thriftpy2, tensorboardX, SQLAlchemy, PyYAML, pymysql, pyluach, pygame, pydantic, psycopg2-binary, multidict, jedi, gymnasium, deprecation, charset-normalizer, blessed, ale-py, shimmy, pycares, gpustat, wrds, stockstats, jqdatasdk, exchange-calendars, AutoROM.accept-rom-license, autorom, aiohttp, aiodns, ray, opencensus, empyrical, ccxt, alpaca-trade-api, aiohttp-cors, pyportfolioopt, pyfolio, stable-baselines3, elegantrl, finrl
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.5
#     Uninstalling msgpack-1.0.5:
#       Successfully uninstalled msgpack-1.0.5
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.20
#     Uninstalling SQLAlchemy-2.0.20:
#       Successfully uninstalled SQLAlchemy-2.0.20
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.1
#     Uninstalling pygame-2.5.1:
#       Successfully uninstalled pygame-2.5.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.2.1
#     Uninstalling pydantic-2.2.1:
#       Successfully uninstalled pydantic-2.2.1
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.0.4
#     Uninstalling multidict-6.0.4:
#       Successfully uninstalled multidict-6.0.4
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.2.0
#     Uninstalling charset-normalizer-3.2.0:
#       Successfully uninstalled charset-normalizer-3.2.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.5
#     Uninstalling aiohttp-3.8.5:
#       Successfully uninstalled aiohttp-3.8.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.49 which is incompatible.
# Successfully installed AutoROM.accept-rom-license-0.6.1 PyYAML-6.0 SQLAlchemy-1.4.49 aiodns-3.0.0 aiohttp-3.8.2 aiohttp-cors-0.7.0 ale-py-0.8.1 alpaca-trade-api-3.0.2 autorom-0.6.1 blessed-1.20.0 box2d-py-2.3.5 ccxt-3.1.60 charset-normalizer-2.1.1 colorful-0.5.5 deprecation-2.1.0 distlib-0.3.7 elegantrl-0.3.6 empyrical-0.5.5 exchange-calendars-4.2.8 farama-notifications-0.0.4 finrl-0.3.6 gpustat-1.1.1 gymnasium-0.29.1 jedi-0.19.0 jqdatasdk-1.9.0 korean-lunar-calendar-0.3.1 msgpack-1.0.3 multidict-5.2.0 nvidia-ml-py-12.535.108 opencensus-0.11.2 opencensus-context-0.1.3 ply-3.11 psycopg2-binary-2.9.7 py-spy-0.3.14 pycares-4.3.0 pydantic-1.10.12 pyfolio-0.9.2 pygame-2.1.0 pyluach-2.2.0 pymysql-1.1.0 pyportfolioopt-1.5.5 ray-2.6.3 shimmy-1.1.0 stable-baselines3-2.1.0 stockstats-0.5.4 swig-4.1.1 tensorboardX-2.6.2.2 thriftpy2-0.4.16 urllib3-1.26.16 virtualenv-20.21.0 websockets-10.4 wrds-3.1.6

# %%
## We also need to install quantstats, because the environment uses it to plot graphs
# !pip install quantstats
# Out:
# Collecting quantstats
#   Downloading QuantStats-0.0.62-py2.py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 975.8 kB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.23.5)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.12.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (3.7.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (1.10.1)
# Requirement already satisfied: tabulate>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.1.70 in /usr/local/lib/python3.10/dist-packages (from quantstats) (0.2.28)
# Requirement already satisfied: python-dateutil>=2.0 in /usr/local/lib/python3.10/dist-packages (from quantstats) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->quantstats) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.0->quantstats) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.0->quantstats) (1.16.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance>=0.1.70->quantstats) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance>=0.1.70->quantstats) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2023.7.22)
# Installing collected packages: quantstats
# Successfully installed quantstats-0.0.62

# %%
## Hide matplotlib warnings
# import warnings
# warnings.filterwarnings('ignore')

import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# %%
import copy
import gym
import torch
import random
import functools

import numpy as np
import torch.nn.functional as F

from tqdm.notebook import tqdm
from collections import deque

from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data.dataset import IterableDataset
from torch.optim import AdamW

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(

# %%
# TOP_BRL = [
#     "ITUB4.SA", "BBDC4.SA", "VALE3.SA", "PETR4.SA", "ABEV3.SA",
#     "BBAS3.SA"
# ]

TOP_BRL = [
    "VALE3.SA", "PETR4.SA", "ITUB4.SA", "BBDC4.SA",
    "BBAS3.SA", "RENT3.SA", "LREN3.SA", "PRIO3.SA",
    "WEGE3.SA", "ABEV3.SA"
]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(len(TOP_BRL))

portfolio_raw_df = YahooDownloader(start_date = '2011-01-01',
                                end_date = '2019-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_raw_df
# Out:
# 10
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (22330, 8)
#              date       open       high        low      close    volume  \
# 0      2011-01-03   8.632311   8.728203   8.630313   5.540226    576145
# 1      2011-01-03  31.500000  31.799999  31.379999  13.617690   3313400
# 2      2011-01-03  11.809763  11.927362  11.724237   6.786199  10862336
# 3      2011-01-03  18.031555  18.250118  17.963253  10.655090  10014663
# 4      2011-01-03   9.264964   9.492898   9.264964   7.161458   3320493
# ...           ...        ...        ...        ...        ...       ...
# 22325  2019-12-30  30.549999  30.709999  30.150000  11.534131  22111600
# 22326  2019-12-30   6.780000   6.832000   6.570000   6.612000   8933500
# 22327  2019-12-30  47.959999  48.290001  47.299999  45.060959   2701600
# 22328  2019-12-30  53.650002  53.860001  53.200001  37.691490  11928100
# 22329  2019-12-30  17.700001  17.740000  17.330000  16.492718   5838200
#
#             tic  day
# 0      ABEV3.SA    0
# 1      BBAS3.SA    0
# 2      BBDC4.SA    0
# 3      ITUB4.SA    0
# 4      LREN3.SA    0
# ...         ...  ...
# 22325  PETR4.SA    0
# 22326  PRIO3.SA    0
# 22327  RENT3.SA    0
# 22328  VALE3.SA    0
# 22329  WEGE3.SA    0
#
# [22330 rows x 8 columns]

# %%
portfolio_raw_df.groupby("tic").count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           date  open  high   low  close  volume   day
# tic
# ABEV3.SA  2233  2233  2233  2233   2233    2233  2233
# BBAS3.SA  2233  2233  2233  2233   2233    2233  2233
# BBDC4.SA  2233  2233  2233  2233   2233    2233  2233
# ITUB4.SA  2233  2233  2233  2233   2233    2233  2233
# LREN3.SA  2233  2233  2233  2233   2233    2233  2233
# PETR4.SA  2233  2233  2233  2233   2233    2233  2233
# PRIO3.SA  2233  2233  2233  2233   2233    2233  2233
# RENT3.SA  2233  2233  2233  2233   2233    2233  2233
# VALE3.SA  2233  2233  2233  2233   2233    2233  2233
# WEGE3.SA  2233  2233  2233  2233   2233    2233  2233

# %%
"""From FinRL https://github.com/AI4Finance-LLC/FinRL/tree/master/finrl/env"""
import gym
import math
import matplotlib
import numpy as np
import pandas as pd
from gym import spaces
from gym.utils import seeding

matplotlib.use("Agg")
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv
from pathlib import Path

try:
    import quantstats as qs
except ModuleNotFoundError:
    raise ModuleNotFoundError(
        """QuantStats module not found, environment can't plot results and calculate indicadors.
        This module is not installed with FinRL. Install by running one of the options:
        pip install quantstats --upgrade --no-cache-dir
        conda install -c ranaroussi quantstats
        """
        )

class PortfolioOptimizationEnv(gym.Env):
    """A portfolio allocantion environment for OpenAI gym.

    This environment simulates the interactions between an agent and the financial market
    based on data provided by a dataframe. The dataframe contains the time series of
    features defined by the user (such as closing, high and low prices) and must have
    a time and a tic column with a list of datetimes and ticker symbols respectively.
    An example of dataframe is shown below::

            date        high            low             close           tic
        0   2020-12-23  0.157414        0.127420        0.136394        ADA-USD
        1   2020-12-23  34.381519       30.074295       31.097898       BNB-USD
        2   2020-12-23  24024.490234    22802.646484    23241.345703    BTC-USD
        3   2020-12-23  0.004735        0.003640        0.003768        DOGE-USD
        4   2020-12-23  637.122803      560.364258      583.714600      ETH-USD
        ... ...         ...             ...             ...             ...

    Based on this dataframe, the environment will create an observation space that can
    be a Dict or a Box. The Box observation space is a three-dimensional array of shape
    (f, n, t), where f is the number of features, n is the number of stocks in the
    portfolio and t is the user-defined time window. If the environment is created with
    the parameter return_last_action set to True, the observation space is a Dict with
    the following keys::

        {
        "state": three-dimensional Box (f, n, t) representing the time series,
        "last_action": one-dimensional Box (n+1,) representing the portfolio weights
        }

    Note that the action space of this environment is an one-dimensional Box with size
    n + 1 because the portfolio weights must contains the weights related to all the
    stocks in the portfolio and to the remaining cash.

    Attributes:
        action_space: Action space.
        observation_space: Observation space.
        episode_length: Number of timesteps of an episode.
    """
    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        initial_amount,
        order_df=True,
        return_last_action=False,
        normalize_df="by_previous_time",
        reward_scaling=1,
        comission_fee_model="trf",
        comission_fee_pct=0,
        features=["close", "high", "low"],
        valuation_feature="close",
        time_column="date",
        time_format="%Y-%m-%d",
        tic_column="tic",
        time_window=1,
        cwd="./",
        new_gym_api=False
    ):
        """Initializes environment's instance.

        Args:
            df: Dataframe with market information over a period of time.
            initial_amount: Initial amount of cash available to be invested.
            order_df: If True input dataframe is ordered by time.
            return_last_action: If True, observations also return the last performed
                action. Note that, in that case, the observation space is a Dict.
            normalize_df: Defines the normalization method applied to input dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
            reward_scaling: A scaling factor to multiply the reward function. This
                factor can help training.
            comission_fee_model: Model used to simulate comission fee. Possible values
                are "trf" (for transaction remainder factor model) and "wvm" (for weights
                vector modifier model). If None, commission fees are not considered.
            comission_fee_pct: Percentage to be used in comission fee. It must be a value
                between 0 and 1.
            features: List of features to be considered in the observation space. The
                items of the list must be names of columns of the input dataframe.
            valuation_feature: Feature to be considered in the portfolio value calculation.
            time_column: Name of the dataframe's column that contain the datetimes that
                index the dataframe.
            time_format: Formatting string of time column.
            tic_name: Name of the dataframe's column that contain ticker symbols.
            time_window: Size of time window.
            cwd: Local repository in which resulting graphs will be saved.
            new_gym_api: If True, the environment will use the new gym api standard for
                step and reset methods.
        """
        # super(StockEnv, self).__init__()
        # money = 10 , scope = 1
        self._time_window = time_window
        self._time_index = time_window - 1
        self._time_column = time_column
        self._time_format = time_format
        self._tic_column = tic_column
        self._df = df
        self._initial_amount = initial_amount
        self._return_last_action = return_last_action
        self._reward_scaling = reward_scaling
        self._comission_fee_pct = comission_fee_pct
        self._comission_fee_model = comission_fee_model
        self._features = features
        self._valuation_feature = valuation_feature
        self._cwd = Path(cwd)
        self._new_gym_api = new_gym_api

        # results file
        self._results_file = self._cwd / "results" / "rl"
        self._results_file.mkdir(parents=True, exist_ok=True)

        # price variation
        self._df_price_variation = None

        # preprocess data
        self._preprocess_data(order_df, normalize_df)

        # dims and spaces
        self._tic_list = self._df[self._tic_column].unique()
        self._stock_dim = len(self._tic_list)
        action_space = 1 + self._stock_dim

        # sort datetimes and define episode length
        self._sorted_times = sorted(set(self._df[time_column]))
        self.episode_length = len(self._sorted_times) - time_window + 1

        # define action space
        self.action_space = spaces.Box(low=0, high=1, shape=(action_space,))

        # define observation state
        if self._return_last_action:
            # if  last action must be returned, a dict observation
            # is defined
            self.observation_space = spaces.Dict({
                "state": spaces.Box(
                    low=-np.inf,
                    high=np.inf,
                    shape=(
                        len(self._features),
                        self._stock_dim,
                        self._time_window
                    )
                ),
                "last_action": spaces.Box(
                    low=0, high=1, shape=(action_space,)
                )
            })
        else:
            # if information about last action is not relevant,
            # a 3D observation space is defined
            self.observation_space = spaces.Box(
                low=-np.inf,
                high=np.inf,
                shape=(
                    len(self._features),
                    self._stock_dim,
                    self._time_window
                ),
            )

        self._reset_memory()

        self._portfolio_value = self._initial_amount
        self._terminal = False

    def step(self, actions):
        """Performs a simulation step.

        Args:
            actions: An unidimensional array containing the new portfolio
                weights.

        Note:
            If the environment was created with "return_last_action" set to
            True, the next state returned will be a Dict. If it's set to False,
            the next state will be a Box. You can check the observation state
            through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, reward, terminal, truncated, info). If it's set to False,
            the following tuple is returned: (state, reward, terminal, info).

            state: Next simulation state.
            reward: Reward related to the last performed action.
            terminal: If True, the environment is in a terminal state.
            truncated: If True, the environment has passed it's simulation
                time limit. Currently, it's always False.
            info: A dictionary containing informations about the last state.
        """
        self._terminal = self._time_index >= len(self._sorted_times) - 1

        if self._terminal:
            metrics_df = pd.DataFrame(
                {"date": self._date_memory,
                 "returns": self._portfolio_return_memory,
                 "rewards": self._portfolio_reward_memory,
                 "portfolio_values": self._asset_memory["final"]}
            )
            metrics_df.set_index("date", inplace=True)

            plt.plot(metrics_df["portfolio_values"], "r")
            plt.title("Portfolio Value Over Time")
            plt.xlabel("Time")
            plt.ylabel("Portfolio value")
            plt.savefig(self._results_file / "portfolio_value.png")
            plt.close()

            plt.plot(self._portfolio_reward_memory, "r")
            plt.title("Reward Over Time")
            plt.xlabel("Time")
            plt.ylabel("Reward")
            plt.savefig(self._results_file / "reward.png")
            plt.close()

            plt.plot(self._actions_memory)
            plt.title("Actions performed")
            plt.xlabel("Time")
            plt.ylabel("Weight")
            plt.savefig(self._results_file / "actions.png")
            plt.close()

            print("=================================")
            print("Initial portfolio value:{}".format(self._asset_memory['final'][0]))
            print("Final portfolio value: {}".format(self._portfolio_value))
            print("Final accumulative portfolio value: {}".format(self._portfolio_value / self._asset_memory['final'][0]))
            print("Maximum DrawDown: {}".format(qs.stats.max_drawdown(metrics_df["portfolio_values"])))
            print("Sharpe ratio: {}".format(qs.stats.sharpe(metrics_df["returns"])))
            print("=================================")

            qs.plots.snapshot(metrics_df["returns"], show=False, savefig=self._results_file / "portfolio_summary.png")

            if self._new_gym_api:
                return self._state, self._reward, self._terminal, False, self._info
            return self._state, self._reward, self._terminal, self._info

        else:
            # transform action to numpy array (if it's a list)
            actions = np.array(actions, dtype=np.float32)

            # if necessary, normalize weights
            if math.isclose(np.sum(actions), 1, abs_tol=1e-6) and np.min(actions) >= 0:
                weights = actions
            else:
                weights = self._softmax_normalization(actions)

            # save initial portfolio weights for this time step
            self._actions_memory.append(weights)

            # get last step final weights and portfolio_value
            last_weights = self._final_weights[-1]

            # load next state
            self._time_index += 1
            self._state, self._info = self._get_state_and_info_from_time_index(self._time_index)

            # if using weights vector modifier, we need to modify weights vector
            if self._comission_fee_model == "wvm":
                delta_weights = weights - last_weights
                delta_assets = delta_weights[1:] # disconsider
                # calculate fees considering weights modification
                fees = np.sum(np.abs(delta_assets * self._portfolio_value))
                if fees > weights[0] * self._portfolio_value:
                    weights = last_weights
                    # maybe add negative reward
                else:
                    portfolio = weights * self._portfolio_value
                    portfolio[0] -= fees
                    self._portfolio_value = np.sum(portfolio) # new portfolio value
                    weights = portfolio / self._portfolio_value # new weights
            elif self._comission_fee_model == "trf":
                last_mu = 1
                mu = 1 - 2 * self._comission_fee_pct + self._comission_fee_pct ** 2
                while abs(mu - last_mu) > 1e-10:
                    last_mu = mu
                    mu = (1 - self._comission_fee_pct * weights[0] -
                          (2 * self._comission_fee_pct - self._comission_fee_pct ** 2) *
                          np.sum(np.maximum(last_weights[1:] - mu * weights[1:], 0))) / (1 - self._comission_fee_pct * weights[0])
                self._info["trf_mu"] = mu
                self._portfolio_value = mu * self._portfolio_value

            # save initial portfolio value of this time step
            self._asset_memory["initial"].append(self._portfolio_value)

            # time passes and time variation changes the portfolio distribution
            portfolio = self._portfolio_value * (weights * self._price_variation)

            # calculate new portfolio value and weights
            self._portfolio_value = np.sum(portfolio)
            weights = portfolio / self._portfolio_value

            # save final portfolio value and weights of this time step
            self._asset_memory["final"].append(self._portfolio_value)
            self._final_weights.append(weights)

            # save date memory
            self._date_memory.append(self._info["end_time"])

            # define portfolio return
            rate_of_return = self._asset_memory["final"][-1] / self._asset_memory["final"][-2]
            portfolio_return = rate_of_return - 1
            portfolio_reward = np.log(rate_of_return)

            # save portfolio return memory
            self._portfolio_return_memory.append(portfolio_return)
            self._portfolio_reward_memory.append(portfolio_reward)

            # Define portfolio return
            self._reward = portfolio_reward
            self._reward = self._reward * self._reward_scaling

        if self._new_gym_api:
            return self._state, self._reward, self._terminal, False, self._info
        return self._state, self._reward, self._terminal, self._info

    def reset(self):
        """Resets the environment and returns it to its initial state (the
        fist date of the dataframe).

        Note:
            If the environment was created with "return_last_action" set to
            True, the initial state will be a Dict. If it's set to False,
            the initial state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            If "new_gym_api" is set to True, the following tuple is returned:
            (state, info). If it's set to False, only the initial state is
            returned.

            state: Initial state.
            info: Initial state info.
        """
        # time_index must start a little bit in the future to implement lookback
        self._time_index = self._time_window - 1
        self._reset_memory()

        self._state, self._info = self._get_state_and_info_from_time_index(self._time_index)
        self._portfolio_value = self._initial_amount
        self._terminal = False

        if self._new_gym_api:
            return self._state, self._info
        return self._state

    def _get_state_and_info_from_time_index(self, time_index):
        """Gets state and information given a time index. It also updates "data"
        attribute with information about the current simulation step.

        Args:
            time_index: An integer that represents the index of a specific datetime.
                The initial datetime of the dataframe is given by 0.

        Note:
            If the environment was created with "return_last_action" set to
            True, the returned state will be a Dict. If it's set to False,
            the returned state will be a Box. You can check the observation
            state through the attribute "observation_space".

        Returns:
            A tuple with the following form: (state, info).

            state: The state of the current time index. It can be a Box or a Dict.
            info: A dictionary with some informations about the current simulation
                step. The dict has the following keys::

                {
                "tics": List of ticker symbols,
                "start_time": Start time of current time window,
                "start_time_index": Index of start time of current time window,
                "end_time": End time of current time window,
                "end_time_index": Index of end time of current time window,
                "data": Data related to the current time window,
                "price_variation": Price variation of current time step
                }
        """
        # returns state in form (channels, tics, timesteps)
        end_time = self._sorted_times[time_index]
        start_time = self._sorted_times[time_index - (self._time_window - 1)]

        # define data to be used in this time step
        self._data = self._df[
            (self._df[self._time_column] >= start_time) &
            (self._df[self._time_column] <= end_time)
        ][[self._time_column, self._tic_column] + self._features]

        # define price variation of this time_step
        self._price_variation = self._df_price_variation[
                self._df_price_variation[self._time_column] == end_time
            ][self._valuation_feature].to_numpy()
        self._price_variation = np.insert(self._price_variation, 0, 1)

        # define state to be returned
        state = None
        for tic in self._tic_list:
            tic_data = self._data[self._data[self._tic_column] == tic]
            tic_data = tic_data[self._features].to_numpy().T
            tic_data = tic_data[..., np.newaxis]
            state = tic_data if state is None else np.append(state, tic_data, axis=2)
        state = state.transpose((0, 2, 1))
        info = {
            "tics": self._tic_list,
            "start_time": start_time,
            "start_time_index": time_index - (self._time_window - 1),
            "end_time": end_time,
            "end_time_index": time_index,
            "data": self._data,
            "price_variation": self._price_variation
        }
        return self._standardize_state(state), info

    def render(self, mode="human"):
        """Renders the environment.

        Returns:
            Observation of current simulation step.
        """
        return self._state

    def _softmax_normalization(self, actions):
        """Normalizes the action vector using softmax function.

        Returns:
            Normalized action vector (portfolio vector).
        """
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator / denominator
        return softmax_output

    def enumerate_portfolio(self):
        """Enumerates the current porfolio by showing the ticker symbols
        of all the investments considered in the portfolio.
        """
        print("Index: 0. Tic: Cash")
        for index, tic in enumerate(self._tic_list):
            print("Index: {}. Tic: {}".format(index + 1, tic))

    def _preprocess_data(self, order, normalize):
        """Orders and normalizes the environment's dataframe.

        Args:
            order: If true, the dataframe will be ordered by ticker list
                and datetime.
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.
        """
        # order time dataframe by tic and time
        if order:
            self._df = self._df.sort_values(by=[self._tic_column, self._time_column])
        # defining price variation after ordering dataframe
        self._df_price_variation = self._temporal_variation_df()
        # apply normalization
        if normalize:
            self._normalize_dataframe(normalize)
        # transform str to datetime
        self._df[self._time_column] = pd.to_datetime(self._df[self._time_column])
        self._df_price_variation[self._time_column] = pd.to_datetime(self._df_price_variation[self._time_column])
        # transform numeric variables to float32 (compatibility with pytorch)
        self._df[self._features] = self._df[self._features].astype("float32")
        self._df_price_variation[self._features] = self._df_price_variation[self._features].astype("float32")

    def _reset_memory(self):
        """Resets the environment's memory."""
        date_time = self._sorted_times[self._time_index]
        # memorize portfolio value each step
        self._asset_memory = {
            "initial" : [self._initial_amount],
            "final" : [self._initial_amount]
        }
        # memorize portfolio return and reward each step
        self._portfolio_return_memory = [0]
        self._portfolio_reward_memory = [0]
        # initial action: all money is allocated in cash
        self._actions_memory = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize portfolio weights at the ending of time step
        self._final_weights = [np.array([1] + [0] * self._stock_dim, dtype=np.float32)]
        # memorize datetimes
        self._date_memory = [date_time]

    def _standardize_state(self, state):
        """Standardize the state given the observation space. If "return_last_action"
        is set to False, a three-dimensional box is returned. If it's set to True, a
        dictionary is returned. The dictionary follows the standard below::

            {
            "state": Three-dimensional box representing the current state,
            "last_action": One-dimensional box representing the last action
            }
        """
        last_action = self._actions_memory[-1]
        if self._return_last_action:
            return { "state": state, "last_action": last_action }
        else:
            return state

    def _normalize_dataframe(self, normalize):
        """"Normalizes the environment's dataframe.

        Args:
            normalize: Defines the normalization method applied to the dataframe.
                Possible values are "by_previous_time", "by_fist_time_window_value",
                "by_COLUMN_NAME" (where COLUMN_NAME must be changed to a real column
                name) and a custom function. If None no normalization is done.

        Note:
            If a custom function is used in the normalization, it must have an
            argument representing the environment's dataframe.
        """
        if type(normalize) == str:
            if normalize == "by_fist_time_window_value":
                print("Normalizing {} by first time window value...".format(self._features))
                self._df = self._temporal_variation_df(self._time_window - 1)
            elif normalize == "by_previous_time":
                print("Normalizing {} by previous time...".format(self._features))
                self._df = self._temporal_variation_df()
            elif normalize.startswith("by_"):
                normalizer_column = normalize[3:]
                print("Normalizing {} by {}".format(self._features, normalizer_column))
                for column in self._features:
                    self._df[column] = self._df[column] / self._df[normalizer_column]
        elif callable(normalize):
            print("Applying custom normalization function...")
            self._df = normalize(self._df)
        else:
            print("No normalization was performed.")


    def _temporal_variation_df(self, periods=1):
        """Calculates the temporal variation dataframe. For each feature, this
        dataframe contains the rate of the current feature's value and the last
        feature's value given a period. It's used to normalize the dataframe.

        Args:
            periods: Periods (in time indexes) to calculate temporal variation.

        Returns:
            Temporal variation dataframe.
        """
        df_temporal_variation = self._df.copy()
        prev_columns = []
        for column in self._features:
            prev_column = "prev_{}".format(column)
            prev_columns.append(prev_column)
            df_temporal_variation[prev_column] = df_temporal_variation.groupby(self._tic_column)[column].shift(periods=periods)
            df_temporal_variation[column] = df_temporal_variation[column] / df_temporal_variation[prev_column]
        df_temporal_variation = df_temporal_variation.drop(columns=prev_columns).fillna(1).reset_index(drop=True)
        return df_temporal_variation

    def _seed(self, seed=None):
        """Seeds the sources of randomness of this environment to guarantee
        reproducibility.

        Args:
            seed: Seed value to be applied.

        Returns:
            Seed value applied.
        """
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self, env_number=1):
        """Generates an environment compatible with Stable Baselines 3. The
        generated environment is a vectorized version of the current one.

        Returns:
            A tuple with the generated environment and an initial observation.
        """
        e = DummyVecEnv([lambda: self] * env_number)
        obs = e.reset()
        return e, obs
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Define Architecture

# %%
# Define constants
PORTFOLIO_SIZE = len(TOP_BRL)

# %% [markdown]
# Create the gradient policy
# The gradient policy below is identical to the EIIE architecture from Jiang et al paper.

# %%
class GradientPolicy(nn.Module):
    def __init__(self):
        """DDPG policy network initializer."""
        super().__init__()

        self.sequential = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=2, kernel_size=(1, 3)),
            nn.ReLU(),
            nn.Conv2d(in_channels=2, out_channels=20, kernel_size=(1, 48)),
            nn.ReLU()
        )

        self.final_convolution = nn.Conv2d(in_channels=21, out_channels=1, kernel_size=(1, 1))

        self.softmax = nn.Sequential(
            nn.Softmax(dim=-1)
        )

    def mu(self, observation, last_action):
        """Defines a most favorable action of this policy given input x.

        Args:
          observation: environment observation .
          last_action: Last action performed by agent.

        Returns:
          Most favorable action.
        """

        if isinstance(observation, np.ndarray):
            observation = torch.from_numpy(observation).to(device)
        if isinstance(last_action, np.ndarray):
            last_action = torch.from_numpy(last_action).to(device)

        last_stocks, cash_bias = self._process_last_action(last_action)

        output = self.sequential(observation) # shape [N, PORTFOLIO_SIZE + 1, 19, 1]
        output = torch.cat([output, last_stocks], dim=1) # shape [N, 21, PORTFOLIO_SIZE, 1]
        output = self.final_convolution(output) # shape [N, 1, PORTFOLIO_SIZE, 1]
        output = torch.cat([output, cash_bias], dim=2) # shape [N, 1, PORTFOLIO_SIZE + 1, 1]

        # output shape must be [N, features] = [1, PORTFOLIO_SIZE + 1], being N batch size (1)
        # and size the number of features (weights vector).
        output = torch.squeeze(output, 3)
        output = torch.squeeze(output, 1) # shape [N, PORTFOLIO_SIZE + 1]

        output = self.softmax(output)

        return output

    def forward(self, observation, last_action):
        """Policy network's forward propagation.

        Args:
          observation: environment observation (dictionary).
          epsilon: exploration noise to be applied.

        Returns:
          Action to be taken (numpy array).
        """
        mu = self.mu(observation, last_action)
        action = mu.cpu().detach().numpy().squeeze()
        return action

    def _process_last_action(self, last_action):
        batch_size = last_action.shape[0]
        stocks = last_action.shape[1] - 1
        last_stocks = last_action[:, 1:].reshape((batch_size, 1, stocks, 1))
        cash_bias = last_action[:, 0].reshape((batch_size, 1, 1, 1))
        return last_stocks, cash_bias

# %% [markdown]
# Portfolio Vector Memory
# The portfolio vector memory is an object that saves all the portfolio vectors generated by the policy. It's useful because the algorithm can get the last action performed, an information necessary to do forward propagation. Read Jiang et al article for more information.

# %%
class PVM:
    def __init__(self, capacity):
        """Initializes portfolio vector memory.

        Args:
          capacity: Max capacity of memory.
        """
        # initially, memory will have the same actions
        self.capacity = capacity
        self.reset()

    def reset(self):
        self.memory = [np.array([1] + [0] * PORTFOLIO_SIZE, dtype=np.float32)] * (self.capacity + 1)
        self.index = 0 # initial index to retrieve data

    def retrieve(self):
        last_action = self.memory[self.index]
        self.index = 0 if self.index == self.capacity else self.index + 1
        return last_action

    def add(self, action):
        self.memory[self.index] = action

# %% [markdown]
# ReplayBuffer and RLDataset
# The replay buffer implemented in this work is slightly different from the one in famous algorithms. Usually, experiences are constantly added to the replay buffer and when it's completely filled, older experiences are overwritten by new ones (deque behavior). A reinforcement learning algorithm can constantly sample experiences from the buffer to update their neural networks and, as the time passes, older experiences will be disconsidered due to the deque behavior.
#
# In this replay buffer, however, the deque behavior is still present, but when an algorithm sample a batch of experiences, all the experiences in the replay buffer are returned and it is cleared. This behavior is necessary given the policy gradient algorithm introduced by Jiang et al.

# %%
class ReplayBuffer:
  def __init__(self, capacity):
    """Initializes replay buffer.

    Args:
      capacity: Max capacity of buffer.
    """
    self.buffer = deque(maxlen=capacity)

  def __len__(self):
    """Represents the size of the buffer

    Returns:
      Size of the buffer.
    """
    return len(self.buffer)

  def append(self, experience):
    """Append experience to buffer. When buffer is full, it pops
       an old experience.

    Args:
      experience: experience to be saved.
    """
    self.buffer.append(experience)

  def sample(self):
    """Sample from replay buffer. All data from replay buffer is
    returned and the buffer is cleared.

    Returns:
      Sample of batch_size size.
    """
    buffer = list(self.buffer)
    self.buffer.clear()
    return buffer

# %%
class RLDataset(IterableDataset):
  def __init__(self, buffer):
    """Initializes reinforcement learning dataset.

    Args:
        buffer: replay buffer to become iterable dataset.

    Note:
        It's a subclass of pytorch's IterableDataset,
        check https://pytorch.org/docs/stable/data.html#torch.utils.data.IterableDataset
    """
    self.buffer = buffer

  def __iter__(self):
    """Iterates over RLDataset.

    Returns:
      Every experience of a sample from replay buffer.
    """
    for experience in self.buffer.sample():
        yield experience

# %% [markdown]
# Create Polyak average function
# The Polyak average function allows us to have a target function that is incrementally updated. It's useful to avoid oscillations in the final policy performance.

# %%
def polyak_average(net, target_net, tau=0.01):
  """Applies polyak average to incrementally update target net.

  Args:
    net: trained neural network.
    target_net: target neural network.
    tau: update rate.
  """
  for qp, tp in zip(net.parameters(), target_net.parameters()):
    tp.data.copy_(tau * qp.data + (1 - tau) * tp.data)

# %% [markdown]
# Create PG class
# This class implements the Policy Gradient algorithm used in Jiang et al paper. This algorithm is inspired by DDPG (deep deterministic policy gradient), but there are a couple of differences:
#
# DDPG is an actor-critic algorithm, so it has an actor and a critic neural network. The algorithm below, however, doesn't have a critic neural network and uses the portfolio value as value function: the policy will be updated to maximize the portfolio value.
# DDPG usually makes use of a noise parameter in the action during training to create an exploratory behavior. PG algorithm, on the other hand, has a full-exploit approach.
# DDPG randomly samples experiences from its replay buffer. The implemented policy gradient, however, samples a sequential batch of experiences in time, to make it possible to calculate the variation of the portfolio value in the batch and use it as value function.
# The algorithm can be described as follows:
#
# Initializes policy network, target policy network (if used) and replay buffer;
# For each episode, do the following:
# For each period of batch_size timesteps, do the following:
# For each timestep, define an action to be performed, simulate the timestep and save the experiences in the replay buffer.
# After batch_size timesteps are simulated, sample the replay buffer.
# Update target policy network (if used).
# Calculate the value function:

# %%
class PG:
    def __init__(self,
                 env,
                 batch_size=100,
                 lr=1e-3,
                 optimizer=AdamW,
                 tau=0.05):
        """Initializes Policy Gradient for portfolio optimization.

          Args:
            env: environment.
            batch_size: batch size to train neural network.
            lr: policy neural network learning rate.
            optim: Optimizer of neural network.
            tau: update rate in Polyak averaging.
        """
        # environment
        self.env = env

        # neural networks
        self.policy = GradientPolicy().to(device)
        self.target_policy = copy.deepcopy(self.policy)
        self.optimizer = optimizer(self.policy.parameters(), lr=lr)
        self.tau = tau

        # replay buffer and portfolio vector memory
        self.batch_size = batch_size
        self.buffer = ReplayBuffer(capacity=batch_size)
        self.pvm = PVM(self.env.episode_length)

        # dataset and dataloader
        dataset = RLDataset(self.buffer)
        self.dataloader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            pin_memory=True)

    def train(self, episodes=100):
        """Training sequence

        Args:
            episodes: Number of episodes to simulate
        """
        for i in tqdm(range(1, episodes + 1)):
            obs = self.env.reset() # observation
            self.pvm.reset() # reset portfolio vector memory
            done = False

            while not done:
                # define last_action and action and update portfolio vector memory
                last_action = self.pvm.retrieve()
                obs_batch = np.expand_dims(obs, axis=0)
                last_action_batch = np.expand_dims(last_action, axis=0)
                action = self.policy(obs_batch, last_action_batch)
                self.pvm.add(action)

                # run simulation step
                next_obs, reward, done, info = self.env.step(action)

                # add experience to replay buffer
                exp = (obs, last_action, info["price_variation"], info["trf_mu"])
                self.buffer.append(exp)

                # update policy networks
                if len(self.buffer) == self.batch_size:
                    self._gradient_ascent()

                obs = next_obs

            # gradient ascent with episode remaining buffer data
            self._gradient_ascent()



    def _gradient_ascent(self):
        # update target neural network
        polyak_average(self.policy, self.target_policy, tau=self.tau)

        # get batch data from dataloader
        obs, last_actions, price_variations, trf_mu = next(iter(self.dataloader))
        obs = obs.to(device)
        last_actions = last_actions.to(device)
        price_variations = price_variations.to(device)
        trf_mu = trf_mu.unsqueeze(1).to(device)

        # define policy loss (negative for gradient ascent)
        mu = self.policy.mu(obs, last_actions)
        policy_loss = - torch.mean(torch.log(torch.sum(mu * price_variations * trf_mu, dim=1)))

        # update policy network
        self.policy.zero_grad()
        policy_loss.backward()
        self.optimizer.step()

# %% [markdown]
# Train Algorithm

# %%
df_portfolio = portfolio_raw_df[["date", "tic", "close", "high", "low"]]

environment = PortfolioOptimizationEnv(
        df_portfolio,
        initial_amount=100000,
        comission_fee_pct=0.0025,
        time_window=50,
        features=["close", "high", "low"]
    )

algo = PG(environment, lr=0.0001)

algo.train(episodes=250)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
#   0%|          | 0/250 [00:00<?, ?it/s]
# =================================
# Initial portfolio value:100000
# Final portfolio value: 360848.4375
# Final accumulative portfolio value: 3.608484375
# Maximum DrawDown: -0.4474641680528296
# Sharpe ratio: 0.7803525399561377
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 360925.6875
# Final accumulative portfolio value: 3.609256875
# Maximum DrawDown: -0.4473952561544139
# Sharpe ratio: 0.7805166407142972
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 360987.6875
# Final accumulative portfolio value: 3.609876875
# Maximum DrawDown: -0.4473258178820573
# Sharpe ratio: 0.780652903510044
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361053.6875
# Final accumulative portfolio value: 3.610536875
# Maximum DrawDown: -0.4472481476147879
# Sharpe ratio: 0.7807950827650563
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361089.625
# Final accumulative portfolio value: 3.61089625
# Maximum DrawDown: -0.4471815083069395
# Sharpe ratio: 0.7808919572067365
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361161.21875
# Final accumulative portfolio value: 3.6116121875
# Maximum DrawDown: -0.44711748591345857
# Sharpe ratio: 0.7810409507727323
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361227.21875
# Final accumulative portfolio value: 3.6122721875
# Maximum DrawDown: -0.4470456819960166
# Sharpe ratio: 0.781182627167457
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361275.34375
# Final accumulative portfolio value: 3.6127534375
# Maximum DrawDown: -0.446993185416971
# Sharpe ratio: 0.781300039222323
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361331.625
# Final accumulative portfolio value: 3.61331625
# Maximum DrawDown: -0.44692318572383705
# Sharpe ratio: 0.7814280374982723
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361406.28125
# Final accumulative portfolio value: 3.6140628125
# Maximum DrawDown: -0.44683974324378806
# Sharpe ratio: 0.7815852097530146
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361464.125
# Final accumulative portfolio value: 3.61464125
# Maximum DrawDown: -0.4467852571862525
# Sharpe ratio: 0.7817156348984424
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361524.5625
# Final accumulative portfolio value: 3.615245625
# Maximum DrawDown: -0.4467082145566226
# Sharpe ratio: 0.7818492840540118
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361580.90625
# Final accumulative portfolio value: 3.6158090625
# Maximum DrawDown: -0.4466452351780871
# Sharpe ratio: 0.7819798566860306
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361642.71875
# Final accumulative portfolio value: 3.6164271875
# Maximum DrawDown: -0.44657304063566106
# Sharpe ratio: 0.7821155111774433
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361716.9375
# Final accumulative portfolio value: 3.617169375
# Maximum DrawDown: -0.44650280924220176
# Sharpe ratio: 0.7822720197099915
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361761.125
# Final accumulative portfolio value: 3.61761125
# Maximum DrawDown: -0.4464347587946995
# Sharpe ratio: 0.7823833191779035
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361842.1875
# Final accumulative portfolio value: 3.618421875
# Maximum DrawDown: -0.446360235323338
# Sharpe ratio: 0.7825488465389518
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361913.6875
# Final accumulative portfolio value: 3.619136875
# Maximum DrawDown: -0.4462850097376677
# Sharpe ratio: 0.7827007345597861
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 361969.125
# Final accumulative portfolio value: 3.61969125
# Maximum DrawDown: -0.4462116024256585
# Sharpe ratio: 0.7828293562000581
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362040.4375
# Final accumulative portfolio value: 3.620404375
# Maximum DrawDown: -0.44614836977706707
# Sharpe ratio: 0.7829827670753923
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362079.375
# Final accumulative portfolio value: 3.62079375
# Maximum DrawDown: -0.44608130050167083
# Sharpe ratio: 0.7830883041763349
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362158.40625
# Final accumulative portfolio value: 3.6215840625
# Maximum DrawDown: -0.4460077958423704
# Sharpe ratio: 0.7832519139640537
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362231.34375
# Final accumulative portfolio value: 3.6223134375
# Maximum DrawDown: -0.445933563254408
# Sharpe ratio: 0.7834062599803954
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362308.15625
# Final accumulative portfolio value: 3.6230815625
# Maximum DrawDown: -0.44585147028075045
# Sharpe ratio: 0.7835675865503915
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362377.46875
# Final accumulative portfolio value: 3.6237746875
# Maximum DrawDown: -0.4457897762226919
# Sharpe ratio: 0.7837185283219888
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362443.96875
# Final accumulative portfolio value: 3.6244396875
# Maximum DrawDown: -0.4457105089954321
# Sharpe ratio: 0.7838655260374358
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362517.625
# Final accumulative portfolio value: 3.62517625
# Maximum DrawDown: -0.4456381521907271
# Sharpe ratio: 0.7840220515962962
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362601.0
# Final accumulative portfolio value: 3.62601
# Maximum DrawDown: -0.4455640155726037
# Sharpe ratio: 0.7841934388193981
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362676.8125
# Final accumulative portfolio value: 3.626768125
# Maximum DrawDown: -0.44549140789347086
# Sharpe ratio: 0.7843548903582025
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362748.5
# Final accumulative portfolio value: 3.627485
# Maximum DrawDown: -0.4454039257533182
# Sharpe ratio: 0.7845085538178004
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362835.40625
# Final accumulative portfolio value: 3.6283540625
# Maximum DrawDown: -0.44532884424713925
# Sharpe ratio: 0.7846863371480979
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362901.15625
# Final accumulative portfolio value: 3.6290115625
# Maximum DrawDown: -0.44525839865350236
# Sharpe ratio: 0.7848343781318554
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 362974.28125
# Final accumulative portfolio value: 3.6297428125
# Maximum DrawDown: -0.44518368485966164
# Sharpe ratio: 0.7849936852007903
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363070.03125
# Final accumulative portfolio value: 3.6307003125
# Maximum DrawDown: -0.44509990376895436
# Sharpe ratio: 0.7851835615817929
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363143.75
# Final accumulative portfolio value: 3.6314375
# Maximum DrawDown: -0.44501666423448893
# Sharpe ratio: 0.7853437502422562
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363228.03125
# Final accumulative portfolio value: 3.6322803125
# Maximum DrawDown: -0.4449375562119716
# Sharpe ratio: 0.7855185982246256
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363309.125
# Final accumulative portfolio value: 3.63309125
# Maximum DrawDown: -0.4448619074833521
# Sharpe ratio: 0.7856878541058485
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363403.1875
# Final accumulative portfolio value: 3.634031875
# Maximum DrawDown: -0.4447801315336697
# Sharpe ratio: 0.785877956872317
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363487.28125
# Final accumulative portfolio value: 3.6348728125
# Maximum DrawDown: -0.44470500018736214
# Sharpe ratio: 0.7860551050426846
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363573.9375
# Final accumulative portfolio value: 3.635739375
# Maximum DrawDown: -0.44461979442989463
# Sharpe ratio: 0.7862367323675455
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363659.09375
# Final accumulative portfolio value: 3.6365909375
# Maximum DrawDown: -0.4445373410265563
# Sharpe ratio: 0.7864173980066003
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363743.9375
# Final accumulative portfolio value: 3.637439375
# Maximum DrawDown: -0.4444546048163649
# Sharpe ratio: 0.7865955588837453
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363835.84375
# Final accumulative portfolio value: 3.6383584375
# Maximum DrawDown: -0.44437098223834604
# Sharpe ratio: 0.7867860307109454
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 363922.0625
# Final accumulative portfolio value: 3.639220625
# Maximum DrawDown: -0.4442846473016574
# Sharpe ratio: 0.7869685845661057
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364021.59375
# Final accumulative portfolio value: 3.6402159375
# Maximum DrawDown: -0.4441945699696218
# Sharpe ratio: 0.787169584019009
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364128.0625
# Final accumulative portfolio value: 3.641280625
# Maximum DrawDown: -0.4441137555338396
# Sharpe ratio: 0.7873818568104147
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364210.625
# Final accumulative portfolio value: 3.64210625
# Maximum DrawDown: -0.44403124763083335
# Sharpe ratio: 0.78755950714525
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364312.0625
# Final accumulative portfolio value: 3.643120625
# Maximum DrawDown: -0.4439392690975933
# Sharpe ratio: 0.7877651510012997
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364396.875
# Final accumulative portfolio value: 3.64396875
# Maximum DrawDown: -0.44385016719473824
# Sharpe ratio: 0.7879462978240087
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364512.71875
# Final accumulative portfolio value: 3.6451271875
# Maximum DrawDown: -0.4437594810710116
# Sharpe ratio: 0.7881734155601474
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364614.59375
# Final accumulative portfolio value: 3.6461459375
# Maximum DrawDown: -0.44367229732176583
# Sharpe ratio: 0.7883808560013881
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364699.625
# Final accumulative portfolio value: 3.64699625
# Maximum DrawDown: -0.44358145279990147
# Sharpe ratio: 0.7885650007885476
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364807.0625
# Final accumulative portfolio value: 3.648070625
# Maximum DrawDown: -0.4434897888184238
# Sharpe ratio: 0.7887808402582343
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364899.34375
# Final accumulative portfolio value: 3.6489934375
# Maximum DrawDown: -0.44339687175880504
# Sharpe ratio: 0.788976599869099
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 364993.40625
# Final accumulative portfolio value: 3.6499340625
# Maximum DrawDown: -0.44331706427848994
# Sharpe ratio: 0.7891752712819659
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365097.09375
# Final accumulative portfolio value: 3.6509709375
# Maximum DrawDown: -0.44321732591586727
# Sharpe ratio: 0.7893862248733546
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365200.75
# Final accumulative portfolio value: 3.6520075
# Maximum DrawDown: -0.44311574400960585
# Sharpe ratio: 0.7895997936993315
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365293.5625
# Final accumulative portfolio value: 3.652935625
# Maximum DrawDown: -0.4430261730271582
# Sharpe ratio: 0.7897962310487556
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365404.9375
# Final accumulative portfolio value: 3.654049375
# Maximum DrawDown: -0.4429338704153837
# Sharpe ratio: 0.7900216498181352
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365500.71875
# Final accumulative portfolio value: 3.6550071875
# Maximum DrawDown: -0.442839703647508
# Sharpe ratio: 0.7902225698932057
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365626.4375
# Final accumulative portfolio value: 3.656264375
# Maximum DrawDown: -0.4427363772195212
# Sharpe ratio: 0.7904694916146029
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365719.25
# Final accumulative portfolio value: 3.6571925
# Maximum DrawDown: -0.4426349032078126
# Sharpe ratio: 0.7906692947744465
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365828.1875
# Final accumulative portfolio value: 3.658281875
# Maximum DrawDown: -0.44254785620238035
# Sharpe ratio: 0.7908906817807877
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 365941.15625
# Final accumulative portfolio value: 3.6594115625
# Maximum DrawDown: -0.4424417379588701
# Sharpe ratio: 0.7911210342216899
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366043.0
# Final accumulative portfolio value: 3.66043
# Maximum DrawDown: -0.44234948552257214
# Sharpe ratio: 0.791334827099814
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366159.46875
# Final accumulative portfolio value: 3.6615946875
# Maximum DrawDown: -0.44224604391322986
# Sharpe ratio: 0.7915683459050478
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366266.03125
# Final accumulative portfolio value: 3.6626603125
# Maximum DrawDown: -0.4421411105378952
# Sharpe ratio: 0.7917894570240429
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366373.5
# Final accumulative portfolio value: 3.663735
# Maximum DrawDown: -0.4420432943011616
# Sharpe ratio: 0.7920135639054836
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366474.09375
# Final accumulative portfolio value: 3.6647409375
# Maximum DrawDown: -0.4419513760222731
# Sharpe ratio: 0.7922271281902745
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366608.03125
# Final accumulative portfolio value: 3.6660803125
# Maximum DrawDown: -0.44183257324430747
# Sharpe ratio: 0.7924905056986584
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366713.21875
# Final accumulative portfolio value: 3.6671321875
# Maximum DrawDown: -0.44173821836593674
# Sharpe ratio: 0.7927102982095563
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366837.65625
# Final accumulative portfolio value: 3.6683765625
# Maximum DrawDown: -0.44163190177115363
# Sharpe ratio: 0.7929595977311339
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 366940.40625
# Final accumulative portfolio value: 3.6694040625
# Maximum DrawDown: -0.44152452183436064
# Sharpe ratio: 0.793177259873797
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367060.875
# Final accumulative portfolio value: 3.67060875
# Maximum DrawDown: -0.4414205446902012
# Sharpe ratio: 0.7934226762060996
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367172.59375
# Final accumulative portfolio value: 3.6717259375
# Maximum DrawDown: -0.4413186307610193
# Sharpe ratio: 0.7936568950422294
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367289.625
# Final accumulative portfolio value: 3.67289625
# Maximum DrawDown: -0.4412036001135905
# Sharpe ratio: 0.793897488657168
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367404.53125
# Final accumulative portfolio value: 3.6740453125
# Maximum DrawDown: -0.44108869131813067
# Sharpe ratio: 0.7941352110797859
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367522.6875
# Final accumulative portfolio value: 3.675226875
# Maximum DrawDown: -0.44098520886856885
# Sharpe ratio: 0.7943780398631379
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367643.0
# Final accumulative portfolio value: 3.67643
# Maximum DrawDown: -0.44088486031840424
# Sharpe ratio: 0.7946235198078074
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367762.875
# Final accumulative portfolio value: 3.67762875
# Maximum DrawDown: -0.44076444881493626
# Sharpe ratio: 0.79487104217992
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367880.90625
# Final accumulative portfolio value: 3.6788090625
# Maximum DrawDown: -0.440672360149715
# Sharpe ratio: 0.7951177722903805
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368004.40625
# Final accumulative portfolio value: 3.6800440625
# Maximum DrawDown: -0.44055232722019566
# Sharpe ratio: 0.795370476432682
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368121.21875
# Final accumulative portfolio value: 3.6812121875
# Maximum DrawDown: -0.4404428556426624
# Sharpe ratio: 0.795615046553055
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368238.21875
# Final accumulative portfolio value: 3.6823821875
# Maximum DrawDown: -0.4403408494760237
# Sharpe ratio: 0.7958593098509695
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368353.0625
# Final accumulative portfolio value: 3.683530625
# Maximum DrawDown: -0.44023020746488184
# Sharpe ratio: 0.7961026820252203
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368486.375
# Final accumulative portfolio value: 3.68486375
# Maximum DrawDown: -0.4401183433791169
# Sharpe ratio: 0.796375094770504
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368609.71875
# Final accumulative portfolio value: 3.6860971875
# Maximum DrawDown: -0.4400035256697947
# Sharpe ratio: 0.7966302364334409
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368708.9375
# Final accumulative portfolio value: 3.687089375
# Maximum DrawDown: -0.43990030788071366
# Sharpe ratio: 0.7968542087280799
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368838.59375
# Final accumulative portfolio value: 3.6883859375
# Maximum DrawDown: -0.4397855449292791
# Sharpe ratio: 0.7971186747840822
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 368971.125
# Final accumulative portfolio value: 3.68971125
# Maximum DrawDown: -0.43966864859474863
# Sharpe ratio: 0.7973890951097139
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 369104.75
# Final accumulative portfolio value: 3.6910475
# Maximum DrawDown: -0.43953886818907584
# Sharpe ratio: 0.7976643930596684
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 369207.34375
# Final accumulative portfolio value: 3.6920734375
# Maximum DrawDown: -0.43942735896875296
# Sharpe ratio: 0.797910549926776
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 369173.1875
# Final accumulative portfolio value: 3.691731875
# Maximum DrawDown: -0.43930502747647826
# Sharpe ratio: 0.7980231371646479
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 367545.84375
# Final accumulative portfolio value: 3.6754584375
# Maximum DrawDown: -0.4379211555734239
# Sharpe ratio: 0.7970202268077494
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 369357.84375
# Final accumulative portfolio value: 3.6935784375
# Maximum DrawDown: -0.4355957981076203
# Sharpe ratio: 0.8011563849086218
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 371480.0
# Final accumulative portfolio value: 3.7148
# Maximum DrawDown: -0.43310718606476106
# Sharpe ratio: 0.8057969736013987
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 374279.53125
# Final accumulative portfolio value: 3.7427953125
# Maximum DrawDown: -0.43005262323222326
# Sharpe ratio: 0.811707318873466
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 376783.21875
# Final accumulative portfolio value: 3.7678321875
# Maximum DrawDown: -0.42674752354785994
# Sharpe ratio: 0.8174359808337043
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 379958.0
# Final accumulative portfolio value: 3.79958
# Maximum DrawDown: -0.42269572231584196
# Sharpe ratio: 0.8244363259887253
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 384040.375
# Final accumulative portfolio value: 3.84040375
# Maximum DrawDown: -0.41774876169776787
# Sharpe ratio: 0.8331388620311662
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 388380.40625
# Final accumulative portfolio value: 3.8838040625
# Maximum DrawDown: -0.41231290299682966
# Sharpe ratio: 0.8424576532244646
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 392859.6875
# Final accumulative portfolio value: 3.928596875
# Maximum DrawDown: -0.40617330013426844
# Sharpe ratio: 0.8522252580743555
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 398654.8125
# Final accumulative portfolio value: 3.986548125
# Maximum DrawDown: -0.3989974414900189
# Sharpe ratio: 0.8641010244020365
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 405844.65625
# Final accumulative portfolio value: 4.0584465625
# Maximum DrawDown: -0.3904913734445088
# Sharpe ratio: 0.8781158822890036
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 413267.125
# Final accumulative portfolio value: 4.13267125
# Maximum DrawDown: -0.38116703388139705
# Sharpe ratio: 0.8924077463429047
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 421595.40625
# Final accumulative portfolio value: 4.2159540625
# Maximum DrawDown: -0.3707688737486736
# Sharpe ratio: 0.9077265266679206
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 430536.9375
# Final accumulative portfolio value: 4.305369375
# Maximum DrawDown: -0.3594866487770697
# Sharpe ratio: 0.9234172465949607
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 440187.625
# Final accumulative portfolio value: 4.40187625
# Maximum DrawDown: -0.3507859529124365
# Sharpe ratio: 0.9392775205865073
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 450963.75
# Final accumulative portfolio value: 4.5096375
# Maximum DrawDown: -0.34304168254585865
# Sharpe ratio: 0.9555387627819167
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 461928.75
# Final accumulative portfolio value: 4.6192875
# Maximum DrawDown: -0.3371571737917486
# Sharpe ratio: 0.9706651882939983
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 473159.625
# Final accumulative portfolio value: 4.73159625
# Maximum DrawDown: -0.3330176106352566
# Sharpe ratio: 0.9844729444989219
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 485482.65625
# Final accumulative portfolio value: 4.8548265625
# Maximum DrawDown: -0.3288263547913356
# Sharpe ratio: 0.9977256193271651
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 497470.875
# Final accumulative portfolio value: 4.97470875
# Maximum DrawDown: -0.32466504423483966
# Sharpe ratio: 1.0087341475206417
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 509322.75
# Final accumulative portfolio value: 5.0932275
# Maximum DrawDown: -0.32099142970026695
# Sharpe ratio: 1.017798219391379
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 520881.0625
# Final accumulative portfolio value: 5.208810625
# Maximum DrawDown: -0.31902592644141214
# Sharpe ratio: 1.0249220355910194
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 532406.1875
# Final accumulative portfolio value: 5.324061875
# Maximum DrawDown: -0.3171029444727206
# Sharpe ratio: 1.0306262447195043
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 542888.0625
# Final accumulative portfolio value: 5.428880625
# Maximum DrawDown: -0.3157367015903104
# Sharpe ratio: 1.0346626579954574
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 551295.75
# Final accumulative portfolio value: 5.5129575
# Maximum DrawDown: -0.3161862867709033
# Sharpe ratio: 1.035813156704935
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 563218.0
# Final accumulative portfolio value: 5.63218
# Maximum DrawDown: -0.31780077163345744
# Sharpe ratio: 1.0386541648676852
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 572789.625
# Final accumulative portfolio value: 5.72789625
# Maximum DrawDown: -0.3192684278062826
# Sharpe ratio: 1.0395284158747493
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 581352.8125
# Final accumulative portfolio value: 5.813528125
# Maximum DrawDown: -0.3206633828419515
# Sharpe ratio: 1.039477694909962
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 589272.125
# Final accumulative portfolio value: 5.89272125
# Maximum DrawDown: -0.3219762907747944
# Sharpe ratio: 1.0388702392752591
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 596738.0
# Final accumulative portfolio value: 5.96738
# Maximum DrawDown: -0.32321220728860356
# Sharpe ratio: 1.0379811896629982
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 603690.0
# Final accumulative portfolio value: 6.0369
# Maximum DrawDown: -0.32435555596929555
# Sharpe ratio: 1.0368306458241372
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 610023.5625
# Final accumulative portfolio value: 6.100235625
# Maximum DrawDown: -0.32541872994878784
# Sharpe ratio: 1.035412481784426
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 615900.75
# Final accumulative portfolio value: 6.1590075
# Maximum DrawDown: -0.32641607982125465
# Sharpe ratio: 1.0338888136613313
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 621309.5625
# Final accumulative portfolio value: 6.213095625
# Maximum DrawDown: -0.3273387704958758
# Sharpe ratio: 1.0322764196716603
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 626363.4375
# Final accumulative portfolio value: 6.263634375
# Maximum DrawDown: -0.3282155019196148
# Sharpe ratio: 1.0306631051045123
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 631095.0
# Final accumulative portfolio value: 6.31095
# Maximum DrawDown: -0.3290317964015237
# Sharpe ratio: 1.02906860137932
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 635529.3125
# Final accumulative portfolio value: 6.355293125
# Maximum DrawDown: -0.3297881835635922
# Sharpe ratio: 1.0275183960527587
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 639507.75
# Final accumulative portfolio value: 6.3950775
# Maximum DrawDown: -0.330491395893048
# Sharpe ratio: 1.0259030407981498
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 643277.0625
# Final accumulative portfolio value: 6.432770625
# Maximum DrawDown: -0.3311573889978179
# Sharpe ratio: 1.024374188659347
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 646835.0
# Final accumulative portfolio value: 6.46835
# Maximum DrawDown: -0.3317847802163387
# Sharpe ratio: 1.022915721778785
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 650107.5625
# Final accumulative portfolio value: 6.501075625
# Maximum DrawDown: -0.3323616464323601
# Sharpe ratio: 1.021480313378958
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 653154.0
# Final accumulative portfolio value: 6.53154
# Maximum DrawDown: -0.33290665082685
# Sharpe ratio: 1.0200889479046458
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 655991.0
# Final accumulative portfolio value: 6.55991
# Maximum DrawDown: -0.33342670038188815
# Sharpe ratio: 1.0187417633963884
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 658713.0625
# Final accumulative portfolio value: 6.587130625
# Maximum DrawDown: -0.33391017852688576
# Sharpe ratio: 1.0174886952866489
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 661219.1875
# Final accumulative portfolio value: 6.612191875
# Maximum DrawDown: -0.334370154844307
# Sharpe ratio: 1.0162577752075095
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 663591.9375
# Final accumulative portfolio value: 6.635919375
# Maximum DrawDown: -0.3348014139600911
# Sharpe ratio: 1.0150908084279775
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 665792.8125
# Final accumulative portfolio value: 6.657928125
# Maximum DrawDown: -0.335208961453782
# Sharpe ratio: 1.0139525040837523
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 667886.5625
# Final accumulative portfolio value: 6.678865625
# Maximum DrawDown: -0.33559709241569435
# Sharpe ratio: 1.0128763606605282
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 669898.9375
# Final accumulative portfolio value: 6.698989375
# Maximum DrawDown: -0.33596319533764907
# Sharpe ratio: 1.0118655840991422
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 671762.5
# Final accumulative portfolio value: 6.717625
# Maximum DrawDown: -0.33631084401324374
# Sharpe ratio: 1.0108779260293559
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 673528.4375
# Final accumulative portfolio value: 6.735284375
# Maximum DrawDown: -0.3366397813802827
# Sharpe ratio: 1.009933592629663
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 675195.75
# Final accumulative portfolio value: 6.7519575
# Maximum DrawDown: -0.3369530502784971
# Sharpe ratio: 1.0090270320827166
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 676779.0
# Final accumulative portfolio value: 6.76779
# Maximum DrawDown: -0.33725241985742815
# Sharpe ratio: 1.0081595114886435
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 678293.0
# Final accumulative portfolio value: 6.78293
# Maximum DrawDown: -0.3375339535466686
# Sharpe ratio: 1.0073356554590351
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 679721.875
# Final accumulative portfolio value: 6.79721875
# Maximum DrawDown: -0.33780888868288794
# Sharpe ratio: 1.0065403175610872
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 681078.875
# Final accumulative portfolio value: 6.81078875
# Maximum DrawDown: -0.33806583013590896
# Sharpe ratio: 1.0057769305265922
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 682370.6875
# Final accumulative portfolio value: 6.823706875
# Maximum DrawDown: -0.3383127653680502
# Sharpe ratio: 1.0050446759676457
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 683617.0
# Final accumulative portfolio value: 6.83617
# Maximum DrawDown: -0.33854661754393833
# Sharpe ratio: 1.0043498348879911
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 684787.25
# Final accumulative portfolio value: 6.8478725
# Maximum DrawDown: -0.33877292056040154
# Sharpe ratio: 1.0036732559946586
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 685838.875
# Final accumulative portfolio value: 6.85838875
# Maximum DrawDown: -0.33899143625167694
# Sharpe ratio: 1.0029922546135703
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 686900.0625
# Final accumulative portfolio value: 6.869000625
# Maximum DrawDown: -0.3391960157434776
# Sharpe ratio: 1.0023652800166127
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 688009.1875
# Final accumulative portfolio value: 6.880091875
# Maximum DrawDown: -0.33939076697110093
# Sharpe ratio: 1.001803736550827
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 688984.25
# Final accumulative portfolio value: 6.8898425
# Maximum DrawDown: -0.3395823672262034
# Sharpe ratio: 1.0012229525217387
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 689935.375
# Final accumulative portfolio value: 6.89935375
# Maximum DrawDown: -0.339763816618741
# Sharpe ratio: 1.0006772254527918
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 690830.9375
# Final accumulative portfolio value: 6.908309375
# Maximum DrawDown: -0.3399395726259967
# Sharpe ratio: 1.0001391739689274
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 691690.625
# Final accumulative portfolio value: 6.91690625
# Maximum DrawDown: -0.340109126274904
# Sharpe ratio: 0.999623787599537
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 692472.5
# Final accumulative portfolio value: 6.924725
# Maximum DrawDown: -0.3402750367766326
# Sharpe ratio: 0.9991171104208523
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 693204.5625
# Final accumulative portfolio value: 6.932045625
# Maximum DrawDown: -0.3404307764081139
# Sharpe ratio: 0.9986151519176928
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 694105.5625
# Final accumulative portfolio value: 6.941055625
# Maximum DrawDown: -0.34057793786400725
# Sharpe ratio: 0.9981995229082679
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 694848.875
# Final accumulative portfolio value: 6.94848875
# Maximum DrawDown: -0.3407229847514269
# Sharpe ratio: 0.9977582909959272
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 695549.6875
# Final accumulative portfolio value: 6.955496875
# Maximum DrawDown: -0.3408627009771301
# Sharpe ratio: 0.9973250431507565
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 696241.25
# Final accumulative portfolio value: 6.9624125
# Maximum DrawDown: -0.3409979934124212
# Sharpe ratio: 0.9969154213464817
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 696907.375
# Final accumulative portfolio value: 6.96907375
# Maximum DrawDown: -0.3411276346029195
# Sharpe ratio: 0.9965188235276548
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 697529.9375
# Final accumulative portfolio value: 6.975299375
# Maximum DrawDown: -0.34125405629952643
# Sharpe ratio: 0.9961252344795956
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 698142.8125
# Final accumulative portfolio value: 6.981428125
# Maximum DrawDown: -0.34137454362754827
# Sharpe ratio: 0.9957505700427701
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 698722.5
# Final accumulative portfolio value: 6.987225
# Maximum DrawDown: -0.3414905543838864
# Sharpe ratio: 0.9953829941673745
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 699298.625
# Final accumulative portfolio value: 6.99298625
# Maximum DrawDown: -0.34160506857802275
# Sharpe ratio: 0.9950364471353284
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 699845.875
# Final accumulative portfolio value: 6.99845875
# Maximum DrawDown: -0.3417123345751386
# Sharpe ratio: 0.9946945242734774
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 700373.4375
# Final accumulative portfolio value: 7.003734375
# Maximum DrawDown: -0.3418193357132324
# Sharpe ratio: 0.9943642559745898
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 700875.5
# Final accumulative portfolio value: 7.008755
# Maximum DrawDown: -0.3419250685692218
# Sharpe ratio: 0.9940397919665709
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 701374.5
# Final accumulative portfolio value: 7.013745
# Maximum DrawDown: -0.34202326594353594
# Sharpe ratio: 0.9937322431469516
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 701855.75
# Final accumulative portfolio value: 7.0185575
# Maximum DrawDown: -0.3421190936206666
# Sharpe ratio: 0.9934327161215728
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 702318.125
# Final accumulative portfolio value: 7.02318125
# Maximum DrawDown: -0.3422118008423075
# Sharpe ratio: 0.9931385654430542
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 702776.75
# Final accumulative portfolio value: 7.0277675
# Maximum DrawDown: -0.3423024924407744
# Sharpe ratio: 0.9928614167619431
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 703208.3125
# Final accumulative portfolio value: 7.032083125
# Maximum DrawDown: -0.3423913073932098
# Sharpe ratio: 0.9925847412432178
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 703646.375
# Final accumulative portfolio value: 7.03646375
# Maximum DrawDown: -0.3424754335407325
# Sharpe ratio: 0.9923254854960545
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704048.0625
# Final accumulative portfolio value: 7.040480625
# Maximum DrawDown: -0.34255900375798176
# Sharpe ratio: 0.9920605431083382
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704451.875
# Final accumulative portfolio value: 7.04451875
# Maximum DrawDown: -0.3426385984651178
# Sharpe ratio: 0.9918153475533006
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 704828.8125
# Final accumulative portfolio value: 7.048288125
# Maximum DrawDown: -0.3427168732083281
# Sharpe ratio: 0.9915666027573242
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705202.125
# Final accumulative portfolio value: 7.05202125
# Maximum DrawDown: -0.34279348772018703
# Sharpe ratio: 0.9913298089366938
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705562.6875
# Final accumulative portfolio value: 7.055626875
# Maximum DrawDown: -0.34286654341246614
# Sharpe ratio: 0.9910964776647574
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 705931.9375
# Final accumulative portfolio value: 7.059319375
# Maximum DrawDown: -0.34293849020823364
# Sharpe ratio: 0.9908803891236035
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706266.0625
# Final accumulative portfolio value: 7.062660625
# Maximum DrawDown: -0.34300758893034544
# Sharpe ratio: 0.9906572000873132
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706600.0625
# Final accumulative portfolio value: 7.066000625
# Maximum DrawDown: -0.3430766570002096
# Sharpe ratio: 0.9904438419245163
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 706921.125
# Final accumulative portfolio value: 7.06921125
# Maximum DrawDown: -0.34314162142796656
# Sharpe ratio: 0.9902367573179124
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707245.4375
# Final accumulative portfolio value: 7.072454375
# Maximum DrawDown: -0.3432061931294277
# Sharpe ratio: 0.9900398789943972
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707551.1875
# Final accumulative portfolio value: 7.075511875
# Maximum DrawDown: -0.3432688087545913
# Sharpe ratio: 0.989842617464364
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 707847.5625
# Final accumulative portfolio value: 7.078475625
# Maximum DrawDown: -0.3433296933211294
# Sharpe ratio: 0.9896504673365665
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708140.375
# Final accumulative portfolio value: 7.08140375
# Maximum DrawDown: -0.343388442049665
# Sharpe ratio: 0.9894653149549536
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708422.875
# Final accumulative portfolio value: 7.08422875
# Maximum DrawDown: -0.3434461444442405
# Sharpe ratio: 0.9892844072760434
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708699.75
# Final accumulative portfolio value: 7.0869975
# Maximum DrawDown: -0.3435027771754062
# Sharpe ratio: 0.9891072644523844
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 708964.125
# Final accumulative portfolio value: 7.08964125
# Maximum DrawDown: -0.3435585913782635
# Sharpe ratio: 0.9889326966975946
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709227.125
# Final accumulative portfolio value: 7.09227125
# Maximum DrawDown: -0.3436112622457683
# Sharpe ratio: 0.9887667590011369
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709475.375
# Final accumulative portfolio value: 7.09475375
# Maximum DrawDown: -0.3436650602236967
# Sharpe ratio: 0.9885983115507982
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709726.5
# Final accumulative portfolio value: 7.097265
# Maximum DrawDown: -0.3437143180104505
# Sharpe ratio: 0.988438943907892
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 709971.25
# Final accumulative portfolio value: 7.0997125
# Maximum DrawDown: -0.3437646745356585
# Sharpe ratio: 0.9882843326678741
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710210.75
# Final accumulative portfolio value: 7.1021075
# Maximum DrawDown: -0.34381212783815696
# Sharpe ratio: 0.9881345653760032
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710434.5
# Final accumulative portfolio value: 7.104345
# Maximum DrawDown: -0.34386083696510283
# Sharpe ratio: 0.9879811936854148
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710659.625
# Final accumulative portfolio value: 7.10659625
# Maximum DrawDown: -0.3439057666679196
# Sharpe ratio: 0.9878356200682595
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 710889.0
# Final accumulative portfolio value: 7.10889
# Maximum DrawDown: -0.3439515848677889
# Sharpe ratio: 0.9876993326453104
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711101.875
# Final accumulative portfolio value: 7.11101875
# Maximum DrawDown: -0.34399670361107615
# Sharpe ratio: 0.9875608862178862
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711303.5625
# Final accumulative portfolio value: 7.113035625
# Maximum DrawDown: -0.34403849801943953
# Sharpe ratio: 0.9874210197787777
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711509.625
# Final accumulative portfolio value: 7.11509625
# Maximum DrawDown: -0.34408001740500505
# Sharpe ratio: 0.9872896249572687
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711710.4375
# Final accumulative portfolio value: 7.117104375
# Maximum DrawDown: -0.34412125582871134
# Sharpe ratio: 0.9871606440651844
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 711906.75
# Final accumulative portfolio value: 7.1190675
# Maximum DrawDown: -0.34416135199645337
# Sharpe ratio: 0.9870357979741347
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712087.3125
# Final accumulative portfolio value: 7.120873125
# Maximum DrawDown: -0.3442022761187534
# Sharpe ratio: 0.9869060543109522
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712281.1875
# Final accumulative portfolio value: 7.122811875
# Maximum DrawDown: -0.3442403367776502
# Sharpe ratio: 0.9867895021759571
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712460.8125
# Final accumulative portfolio value: 7.124608125
# Maximum DrawDown: -0.3442755405372294
# Sharpe ratio: 0.986669842637731
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712639.1875
# Final accumulative portfolio value: 7.126391875
# Maximum DrawDown: -0.3443131792919707
# Sharpe ratio: 0.9865549914168346
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712815.0625
# Final accumulative portfolio value: 7.128150625
# Maximum DrawDown: -0.34434850041648113
# Sharpe ratio: 0.9864441459590227
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 712980.25
# Final accumulative portfolio value: 7.1298025
# Maximum DrawDown: -0.34438432365863736
# Sharpe ratio: 0.9863299292509947
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713139.9375
# Final accumulative portfolio value: 7.131399375
# Maximum DrawDown: -0.34441892343106373
# Sharpe ratio: 0.9862184132136252
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713306.6875
# Final accumulative portfolio value: 7.133066875
# Maximum DrawDown: -0.34445307510192713
# Sharpe ratio: 0.9861152085414615
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713466.1875
# Final accumulative portfolio value: 7.134661875
# Maximum DrawDown: -0.3444859941755949
# Sharpe ratio: 0.9860112257215741
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713617.4375
# Final accumulative portfolio value: 7.136174375
# Maximum DrawDown: -0.3445189363718886
# Sharpe ratio: 0.9859064527964041
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713772.9375
# Final accumulative portfolio value: 7.137729375
# Maximum DrawDown: -0.34454971209397167
# Sharpe ratio: 0.9858088070011195
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 713918.9375
# Final accumulative portfolio value: 7.139189375
# Maximum DrawDown: -0.3445811351881747
# Sharpe ratio: 0.9857105080397419
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714068.1875
# Final accumulative portfolio value: 7.140681875
# Maximum DrawDown: -0.3446103950919176
# Sharpe ratio: 0.9856159014435488
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714212.0
# Final accumulative portfolio value: 7.14212
# Maximum DrawDown: -0.3446397718873949
# Sharpe ratio: 0.985523205440454
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714348.25
# Final accumulative portfolio value: 7.1434825
# Maximum DrawDown: -0.3446696460543974
# Sharpe ratio: 0.9854296477870819
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714490.25
# Final accumulative portfolio value: 7.1449025
# Maximum DrawDown: -0.3446975701750502
# Sharpe ratio: 0.9853426591868175
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714617.375
# Final accumulative portfolio value: 7.14617375
# Maximum DrawDown: -0.3447255507871433
# Sharpe ratio: 0.9852518542476554
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714752.5625
# Final accumulative portfolio value: 7.147525625
# Maximum DrawDown: -0.34475280614474924
# Sharpe ratio: 0.9851676658185806
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 714878.6875
# Final accumulative portfolio value: 7.148786875
# Maximum DrawDown: -0.3447792018472252
# Sharpe ratio: 0.9850818337877639
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715004.625
# Final accumulative portfolio value: 7.15004625
# Maximum DrawDown: -0.3448062953982003
# Sharpe ratio: 0.9849991431073757
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715127.5625
# Final accumulative portfolio value: 7.151275625
# Maximum DrawDown: -0.3448321856929062
# Sharpe ratio: 0.9849171505326648
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715249.5
# Final accumulative portfolio value: 7.152495
# Maximum DrawDown: -0.34485675809440497
# Sharpe ratio: 0.9848383060992565
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715363.0625
# Final accumulative portfolio value: 7.153630625
# Maximum DrawDown: -0.3448821409714431
# Sharpe ratio: 0.984757071591619
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715478.0625
# Final accumulative portfolio value: 7.154780625
# Maximum DrawDown: -0.34490667566068545
# Sharpe ratio: 0.9846802325597173
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715599.875
# Final accumulative portfolio value: 7.15599875
# Maximum DrawDown: -0.3449292724683085
# Sharpe ratio: 0.984609526239591
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715711.0
# Final accumulative portfolio value: 7.15711
# Maximum DrawDown: -0.3449519885142913
# Sharpe ratio: 0.984535839548623
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715815.5
# Final accumulative portfolio value: 7.158155
# Maximum DrawDown: -0.344976904404085
# Sharpe ratio: 0.9844611265318072
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 715925.3125
# Final accumulative portfolio value: 7.159253125
# Maximum DrawDown: -0.3449995111512788
# Sharpe ratio: 0.9843919152433722
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716028.625
# Final accumulative portfolio value: 7.16028625
# Maximum DrawDown: -0.3450209842951
# Sharpe ratio: 0.9843196524444743
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716135.375
# Final accumulative portfolio value: 7.16135375
# Maximum DrawDown: -0.34504209586217327
# Sharpe ratio: 0.9842541180959133
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716238.4375
# Final accumulative portfolio value: 7.162384375
# Maximum DrawDown: -0.3450623653789836
# Sharpe ratio: 0.9841872601952377
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716329.3125
# Final accumulative portfolio value: 7.163293125
# Maximum DrawDown: -0.3450844716605702
# Sharpe ratio: 0.9841174940059292
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716435.1875
# Final accumulative portfolio value: 7.164351875
# Maximum DrawDown: -0.34510371774458837
# Sharpe ratio: 0.9840576801260871
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716520.6875
# Final accumulative portfolio value: 7.165206875
# Maximum DrawDown: -0.3451246756206672
# Sharpe ratio: 0.9839873137449873
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716618.3125
# Final accumulative portfolio value: 7.166183125
# Maximum DrawDown: -0.3451451698271456
# Sharpe ratio: 0.9839272180025763
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716708.625
# Final accumulative portfolio value: 7.16708625
# Maximum DrawDown: -0.3451650112878293
# Sharpe ratio: 0.983864541018966
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716804.0625
# Final accumulative portfolio value: 7.168040625
# Maximum DrawDown: -0.3451822324423125
# Sharpe ratio: 0.9838090737226892
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716893.125
# Final accumulative portfolio value: 7.16893125
# Maximum DrawDown: -0.3452011234121942
# Sharpe ratio: 0.9837487868804227
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 716977.25
# Final accumulative portfolio value: 7.1697725
# Maximum DrawDown: -0.34521819607056403
# Sharpe ratio: 0.9836887746586543
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717069.75
# Final accumulative portfolio value: 7.1706975
# Maximum DrawDown: -0.34523677270948105
# Sharpe ratio: 0.9836367812424426
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717149.4375
# Final accumulative portfolio value: 7.171494375
# Maximum DrawDown: -0.3452553705106459
# Sharpe ratio: 0.9835792341116107
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 717233.625
# Final accumulative portfolio value: 7.17233625
# Maximum DrawDown: -0.3452722937408237
# Sharpe ratio: 0.9835245736786618
# =================================

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Save Model

# %%
torch.save(algo.target_policy.state_dict(), "policy_EIIE.pt")

# %% [markdown]
# Test Model
# Define test periods
# In this work, we are going to use three annual test periods: the year of 2020, 2021 and 2022. To get data from Yahoo Finance, we do just like in the training data.

# %%
portfolio_2020_raw_df = YahooDownloader(start_date = '2020-01-01',
                                end_date = '2020-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2021_raw_df = YahooDownloader(start_date = '2021-01-01',
                                end_date = '2021-12-31',
                                ticker_list = TOP_BRL).fetch_data()
portfolio_2022_raw_df = YahooDownloader(start_date = '2022-01-01',
                                end_date = '2022-12-31',
                                ticker_list = TOP_BRL).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (2480, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (2470, 8)
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (2500, 8)

# %%
portfolio_2020_raw_df.groupby("tic").count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   248   248   248  248    248     248  248
# BBAS3.SA   248   248   248  248    248     248  248
# BBDC4.SA   248   248   248  248    248     248  248
# ITUB4.SA   248   248   248  248    248     248  248
# LREN3.SA   248   248   248  248    248     248  248
# PETR4.SA   248   248   248  248    248     248  248
# PRIO3.SA   248   248   248  248    248     248  248
# RENT3.SA   248   248   248  248    248     248  248
# VALE3.SA   248   248   248  248    248     248  248
# WEGE3.SA   248   248   248  248    248     248  248

# %%
portfolio_2021_raw_df.groupby("tic").count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   247   247   247  247    247     247  247
# BBAS3.SA   247   247   247  247    247     247  247
# BBDC4.SA   247   247   247  247    247     247  247
# ITUB4.SA   247   247   247  247    247     247  247
# LREN3.SA   247   247   247  247    247     247  247
# PETR4.SA   247   247   247  247    247     247  247
# PRIO3.SA   247   247   247  247    247     247  247
# RENT3.SA   247   247   247  247    247     247  247
# VALE3.SA   247   247   247  247    247     247  247
# WEGE3.SA   247   247   247  247    247     247  247

# %%
portfolio_2022_raw_df.groupby("tic").count()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           date  open  high  low  close  volume  day
# tic
# ABEV3.SA   250   250   250  250    250     250  250
# BBAS3.SA   250   250   250  250    250     250  250
# BBDC4.SA   250   250   250  250    250     250  250
# ITUB4.SA   250   250   250  250    250     250  250
# LREN3.SA   250   250   250  250    250     250  250
# PETR4.SA   250   250   250  250    250     250  250
# PRIO3.SA   250   250   250  250    250     250  250
# RENT3.SA   250   250   250  250    250     250  250
# VALE3.SA   250   250   250  250    250     250  250
# WEGE3.SA   250   250   250  250    250     250  250

# %% [markdown]
# Instantiate different environments
# Since we have three different periods of time, we need three different environments instantiated to simulate them.

# %%
df_portfolio_2020 = portfolio_2020_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2021 = portfolio_2021_raw_df[["date", "tic", "close", "high", "low"]]
df_portfolio_2022 = portfolio_2022_raw_df[["date", "tic", "close", "high", "low"]]

environment_2020 = PortfolioOptimizationEnv(
    df_portfolio_2020,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2021 = PortfolioOptimizationEnv(
    df_portfolio_2021,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)

environment_2022 = PortfolioOptimizationEnv(
    df_portfolio_2022,
    initial_amount=100000,
    comission_fee_pct=0.0025,
    time_window=50,
    features=["close", "high", "low"]
)
# Out:
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...
# Normalizing ['close', 'high', 'low'] by previous time...

# %% [markdown]
# Test EIIE architecture
# Now, we can test the EIIE architecture in the three different test periods. It's important no note three things:
#
# In this code, we load the saved policy even though it's not necessary just to show how to save and load your model;
# It's important to reset the environment before an episode and to create a new PVM (portfolio vector memory) for each case
# The neural network is expecting a batch of data, so it's necessary to create an additional dimension to the input data if it's a single item.

# %%
EIIE_results = {
    "training": environment._asset_memory["final"],
    "2020": {},
    "2021": {},
    "2022": {}
}

policy = GradientPolicy()
policy.load_state_dict(torch.load("policy_EIIE.pt"))
policy = policy.to(device)

# 2020
done = False
obs = environment_2020.reset()
pvm = PVM(environment_2020.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2020.step(action)
EIIE_results["2020"]["value"] = environment_2020._asset_memory["final"]
# 2021
done = False
obs = environment_2021.reset()
pvm = PVM(environment_2021.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    observation, _, done, _ = environment_2021.step(action)
EIIE_results["2021"]["value"] = environment_2021._asset_memory["final"]

# 2022
done = False
obs = environment_2022.reset()
pvm = PVM(environment_2022.episode_length)
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_2022.step(action)
EIIE_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 219401.984375
# Final accumulative portfolio value: 2.19401984375
# Maximum DrawDown: -0.23380187500000005
# Sharpe ratio: 2.126126986587572
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 90849.6171875
# Final accumulative portfolio value: 0.908496171875
# Maximum DrawDown: -0.21767757532076548
# Sharpe ratio: -0.25042766580460324
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 128739.3046875
# Final accumulative portfolio value: 1.287393046875
# Maximum DrawDown: -0.3516955667327314
# Sharpe ratio: 1.069406775884612
# =================================

# %% [markdown]
# Test Uniform Buy and Hold
# For comparison, we will also test the performance of a uniform buy and hold strategy. In this strategy, the portfolio has no remaining cash and the same percentage of money is allocated in each asset.

# %%
UBAH_results = {
    "train": {},
    "2020": {},
    "2021": {},
    "2022": {}
}

# train period
terminated = False
environment.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment.step(action)
UBAH_results["train"]["value"] = environment._asset_memory["final"]

# 2020
terminated = False
environment_2020.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2020.step(action)
UBAH_results["2020"]["value"] = environment_2020._asset_memory["final"]

# 2021
terminated = False
environment_2021.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2021.step(action)
UBAH_results["2021"]["value"] = environment_2021._asset_memory["final"]

# 2022
terminated = False
environment_2022.reset()
while not terminated:
    action = [0] + [1/PORTFOLIO_SIZE] * PORTFOLIO_SIZE
    _, _, terminated, _ = environment_2022.step(action)
UBAH_results["2022"]["value"] = environment_2022._asset_memory["final"]
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 404691.3125
# Final accumulative portfolio value: 4.046913125
# Maximum DrawDown: -0.478752581880559
# Sharpe ratio: 0.7871989014240468
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 171127.0
# Final accumulative portfolio value: 1.71127
# Maximum DrawDown: -0.25080226562499996
# Sharpe ratio: 1.7124460903070338
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 95734.4296875
# Final accumulative portfolio value: 0.957344296875
# Maximum DrawDown: -0.1729308466675572
# Sharpe ratio: -0.15519616857972787
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 114168.4921875
# Final accumulative portfolio value: 1.141684921875
# Maximum DrawDown: -0.16239848605544183
# Sharpe ratio: 0.8454506260495201
# =================================

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Plot graphics

# %%
import matplotlib.pyplot as plt

plt.plot(UBAH_results["train"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["training"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in training period")
plt.legend()

plt.show()

# %%
plt.plot(UBAH_results["2020"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2020"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in 2020")
plt.legend()

plt.show()

# %%
plt.plot(UBAH_results["2021"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2021"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in 2021")
plt.legend()

plt.show()

# %%
plt.plot(UBAH_results["2022"]["value"], label="Buy and Hold")
plt.plot(EIIE_results["2022"]["value"], label="EIIE")

plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.title("Performance in 2022")
plt.legend()

plt.show()
